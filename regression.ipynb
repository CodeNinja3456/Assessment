# %%
import pandas

# %%
income=pandas.read_csv('income.csv')
income
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
income.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
array=income.values
X=array[:,0:2]
X
Y=array[:,2]
Y
# Out:
# array([30450, 35670, 31580, 40130, 47830, 41630, 41340, 37650, 40250,
#        45150, 27840, 46110, 36720, 34800, 51300, 38900, 63600, 30870,
#        44190, 48700])

# %%
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
prediction=model.predict(x_test)
print('Predictions are',prediction)
print(' actual answers are',y_test)
# Out:
# Predictions are [31381.8 31381.8 38031.  34666.9 38977.2 41973.8]
#  actual answers are [30450 30870 38900 35670 40250 41630]

# %%
from sklearn.metrics import r2_score
check_accuracy=r2_score(prediction,y_test)*100
check_accuracy
# Out:
# 95.02598421796495

# %%
income=[[30,10]]
model.predict(income)
# Out:
# array([47827.3])
